# %% [markdown]
# <a href="https://colab.research.google.com/github/Zurezh/01-Data-Science/blob/master/02%20Linear%20Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression
#
# **Introduction to Linear Regression and Specifying the Problem**
#
# Data Scientist approach to Solve a problem
# 1. Formulate Question
# 2. Gather Data
# 3. Clean Data
# 4. Explore and Visualize
# 5. Train Algorith (In this case Linear Regression)
# 6. Evaluate
#
# **Formulate Question**
# "Can we use movie budgets to predict move revenue?"
#
# https://github.com/Zurezh/01-Data-Science/blob/master/RevenueBudget.png
#
# Revenue in Y-Axis: Data Scientist calls as Dependent variable; ML calls as Target
# Budget in X-Axis: Data Scientist calls as Independent variable; ML calls as Feature
#
#
# **Gather Data**
# 1. Data on feature -> Movie budgets in USD
# 2. Data on target -> Move revenue in USD <br />
# https://www.the-numbers.com/movie/budgets/all
#
# **Clean Data** Steps
# Missing Data
# Incomplete Data
# Inaccurate Data
# Formatting
#
# **Explore and Visualize**

# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('https://raw.githubusercontent.com/Zurezh/01-Data-Science/master/cost-revenue-clean.csv')

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
X = DataFrame(data,columns=['production_budget_usd'])
y = DataFrame(data,columns=['worldwide_gross_usd'])

# %%
plt.figure(figsize = (10,6))
plt.scatter(X,y,alpha=0.3)
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()

# %% [markdown]
# ## Regression Theory
# ### Linear Regression
#
# ![LinearRegression.PNG](attachment:LinearRegression.PNG)
#
# y intercepts at 10
# y increases by 1, when x increases by 2
# so, the equation is like y=1/2x + 10 which is a slope
#
# **y = mx + c**
#
# ![LR_Intercept.PNG](attachment:LR_Intercept.PNG)
#
# Now, in ML the intercept and the slope is referred as Parameters
#
# In this case, the c is considered as constant and slope coeffiecient (m). And also change the order like below.
#
# ![ML_LineEquation.PNG](attachment:ML_LineEquation.PNG)
#
# **Fitted Value: The expected line value. The point on the line <br />
# Residual: the difference between expected line value and actual value. The actual data value**
# ![ResidualFitted.PNG](attachment:ResidualFitted.PNG)
#
# **Squaring the Residuals**
# The sum of the Squared Residuals. This is the number the Linear Regression tries to minimize to choose the best parameters for the line
# ![SquaringTheResiduals.PNG](attachment:SquaringTheResiduals.PNG)
#
# In other words to find the best possible fit for our regression what we need to do is we need to choose an intercept that theta zero and we need to choose the slope theta one that minimizes the sum of the squared residuals and you will see this number also being referred to as the residual sum of squares or RSS
# ![ResidualSumOfSquares.PNG](attachment:ResidualSumOfSquares.PNG)

# %%
regression = LinearRegression()
regression.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Slope Coefficient:

# %%
regression.coef_  # theta_1
# Out:
# array([[3.11150918]])

# %%
# Intercept
regression.intercept_ # theta_0
# Out:
# array([-7236192.72913958])

# %%
plt.figure(figsize = (10,6))
plt.scatter(X,y,alpha=0.3)

plt.plot(X,regression.predict(X),color='red',linewidth=4)

plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()

# %% [markdown]
# ![Predict_50m.PNG](attachment:Predict_50m.PNG)
# ![Predict_50mChart.PNG](attachment:Predict_50mChart.PNG)

# %%
regression.score(X,y) # Goodness of Fit: R Squared
# Out:
# 0.5496485356985729
